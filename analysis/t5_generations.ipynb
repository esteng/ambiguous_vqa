# %%
import json 
import pathlib 

def read_test_data(test_data_path):
    questions = test_data_path.joinpath("questions.json")
    annotations = test_data_path.joinpath("annotations.json")
    questions = json.load(open(questions))
    annotations = json.load(open(annotations))
    return questions['questions'], annotations['annotations']

def read_generations(output_path):
    flat_data_by_qid = {}
    data = open(output_path).readlines()
    for line in data:
        batch_data = json.loads(line)
        for qid, generation in zip(batch_data['question_id'], batch_data['speaker_utterances'][0]):
            flat_data_by_qid[qid] = generation
    return flat_data_by_qid

# %%
test_data_path = pathlib.Path("/brtx/603-nvme2/estengel/annotator_uncertainty/vqa/dev_from_mturk")
output_path = pathlib.Path("/brtx/602-nvme1/estengel/annotator_uncertainty/models/img2q_t5_small//output/predictions.jsonl")


questions, annotations = read_test_data(test_data_path)
pred_data = read_generations(output_path)
for question, annotation in zip(questions, annotations): 
    qid = question['question_id']
    # print(pred_data.keys())
    pred_text = pred_data[qid]
    print(question['question'])
    print(annotation['answers'][0]['answer'])
    print(pred_text)
    print()
# Out:
# What letters are attached to the pole?
# anne frank
# <pad> What does the sign say?</s><pad><pad><pad>
#
# What letters are attached to the pole?
# jordaan westerkerk anne frank huis, homo-monument, oosterpark dam de nieuwe kerk
# <pad> What is the name of the street?</s><pad><pad><pad><pad>
#
# What letters are attached to the pole?
# jordaan westerkerk anne frank huis homo - monument
# <pad> What is the name of the street?</s><pad>
#
# What letters are attached to the pole?
# jordaan,westerkerk
# <pad> What is the name of the street?</s><pad><pad><pad><pad>
#
# What letters are attached to the pole?
# white
# <pad> What color is the sign?</s><pad><pad><pad><pad><pad>
#
# What railway does this train run along?
# us
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What railway does this train run along?
# bnsf
# <pad> What number is on the train?</s><pad><pad><pad><pad>
#
# What railway does this train run along?
# union pacific
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad>
#
# What railway does this train run along?
# grand canyon
# <pad> What is the name of the train?</s><pad><pad><pad>
#
# What railway does this train run along?
# desert
# <pad> What is in the background?</s><pad><pad><pad><pad><pad><pad>
#
# What railway does this train run along?
# southwest
# <pad> Which direction is the train going?</s><pad><pad><pad><pad><pad>
#
# What railway does this train run along?
# rockies
# <pad> What is the name of the city?</s><pad><pad><pad><pad>
#
# What railway does this train run along?
# western
# <pad> What is the landscape of the picture?</s><pad><pad><pad><pad>
#
# What railway does this train run along?
# train tracks
# <pad> What is the train on?</s><pad><pad><pad><pad><pad>
#
# What's in the canisters?
# spices
# <pad> What is in the fridge?</s><pad><pad><pad><pad><pad><pad>
#
# What's in the canisters?
# cannot tell
# <pad> What is the man holding?</s><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# drink
# <pad> What is the man holding?</s><pad><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# breakfast
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# dinner
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# kitchen
# <pad> What room is this?</s><pad><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# bottle
# <pad> What is the man holding?</s><pad><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# dishes
# <pad> What is in the fridge?</s><pad><pad><pad><pad><pad>
#
# What is the woman arranging?
# bottles
# <pad> What is in the fridge?</s><pad><pad><pad><pad><pad>
#
# What is on the computer screen?
# web page
# <pad> What is the laptop on?</s><pad><pad><pad><pad><pad>
#
# What is on the computer screen?
# internet
# <pad> What is the name of the computer?</s><pad><pad><pad><pad>
#
# What is on the computer screen?
# words
# <pad> What is the name of the company on the laptop?</s><pad>
#
# What is on the computer screen?
# windows
# <pad> What is the laptop sitting on?</s><pad><pad><pad><pad><pad>
#
# What is on the computer screen?
# webpage
# <pad> What is the name of the company on the laptop?</s><pad>
#
# What is on the computer screen?
# banana and strawberry
# <pad> What fruit is this?</s><pad><pad><pad><pad><pad><pad>
#
# What is on the computer screen?
# fruit
# <pad> What is the fruit?</s><pad><pad><pad><pad><pad><pad>
#
# What is on the computer screen?
# banana
# <pad> What fruit is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What is the train for?
# hauling
# <pad> What is the train carrying?</s><pad><pad><pad><pad><pad><pad>
#
# What is the train for?
# travel
# <pad> What is the train doing?</s><pad><pad><pad><pad><pad><pad>
#
# What is the train for?
# transport
# <pad> What is the train used for?</s><pad><pad><pad><pad><pad>
#
# What is the train for?
# moving cargo
# <pad> What is the train carrying?</s><pad><pad><pad><pad><pad>
#
# What is the train for?
# industrial
# <pad> What kind of building is this?</s><pad><pad><pad><pad><pad>
#
# What is the train for?
# freight train
# <pad> What kind of train is this?</s><pad><pad>
#
# What is the train for?
# people
# <pad> What is the purpose of the train?</s><pad>
#
# What is the train for?
# cargo
# <pad> What is the train carrying?</s><pad><pad><pad><pad><pad><pad>
#
# What brand is the snowboard?
# rie
# <pad> What is the name of the skier?</s><pad><pad><pad>
#
# What brand is the snowboard?
# aztec
# <pad> What is the brand of the snowboard?</s><pad><pad><pad><pad>
#
# What brand is the snowboard?
# crown
# <pad> What is the man holding?</s><pad><pad><pad>
#
# What brand is the snowboard?
# mm
# <pad> What is the number on the man's shirt?</s><pad>
#
# What brand is the snowboard?
# artec
# <pad> What is the name of the company on the snowboard?</s>
#
# What brand is the snowboard?
# can't read it
# <pad> What is the word on the sign?</s><pad><pad><pad><pad>
#
# What brand is the snowboard?
# unknown
# <pad> What is the name of the company on the left?</s>
#
# What brand is the snowboard?
# snowboarding
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# left
# <pad> Which man is wearing a hat?</s><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# top left
# <pad> Which man is wearing a hat?</s><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# on left
# <pad> Which person is wearing glasses?</s><pad><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# at table
# <pad> Where are the people?</s><pad><pad><pad><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# background
# <pad> Where is the man standing?</s><pad><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# sitting
# <pad> What are the people doing?</s><pad><pad><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# side of picture
# <pad> Where is the man looking?</s><pad><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# church
# <pad> What is the name of the building?</s><pad><pad><pad><pad>
#
# Where is the lady with the big Red Hat?
# style
# <pad> What is the man in the background doing?</s><pad><pad><pad>
#
# Where is this picture taken?
# alaska
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad>
#
# Where is this picture taken?
# salt flats
# <pad> What is the name of the park?</s><pad><pad><pad>
#
# Where is this picture taken?
# salt desert
# <pad> What is the road made of?</s><pad><pad>
#
# Where is this picture taken?
# at sand flat
# <pad> What is the terrain?</s><pad><pad><pad><pad><pad><pad><pad>
#
# Where is this picture taken?
# outside
# <pad> Where is the man?</s><pad><pad><pad><pad><pad><pad>
#
# Where is this picture taken?
# studio
# <pad> What is the man riding?</s><pad><pad><pad><pad><pad><pad>
#
# Where is this picture taken?
# mountains
# <pad> What is in the background?</s><pad><pad><pad><pad><pad><pad>
#
# Where is this picture taken?
# snow
# <pad> What is the surface of the photo?</s><pad><pad><pad><pad>
#
# What are the pizzas on?
# tray
# <pad> What is the pizza sitting on?</s><pad><pad><pad><pad>
#
# What are the pizzas on?
# pan
# <pad> What is the pizza sitting on?</s><pad><pad><pad><pad><pad>
#
# What are the pizzas on?
# metal pan
# <pad> What is the pizza on?</s><pad><pad><pad><pad><pad>
#
# What are the pizzas on?
# plate
# <pad> What is the pizza sitting on?</s><pad><pad><pad><pad><pad>
#
# What are the pizzas on?
# plates
# <pad> What is the pizza sitting on?</s><pad><pad>
#
# What are the pizzas on?
# cheese
# <pad> What is the pizza topping?</s><pad><pad><pad><pad><pad><pad>
#
# What are the pizzas on?
# pepperoni and cheese
# <pad> What toppings are on the pizza?</s><pad>
#
# What type of truck is this?
# gravel
# <pad> What is the truck laying on?</s><pad><pad><pad><pad>
#
# What type of truck is this?
# hauling truck
# <pad> What is the truck hauling?</s><pad><pad><pad><pad><pad>
#
# What type of truck is this?
# mitsubishi
# <pad> What brand is the truck?</s><pad><pad><pad><pad><pad><pad>
#
# What type of truck is this?
# dumper truck
# <pad> What is the truck parked on?</s><pad><pad><pad><pad>
#
# What type of truck is this?
# dump
# <pad> What kind of truck is this?</s><pad><pad><pad><pad><pad>
#
# What type of truck is this?
# semi
# <pad> What kind of truck is this?</s><pad><pad><pad><pad><pad>
#
# Where is the mattress?
# on bed
# <pad> Where is the bed?</s><pad><pad><pad><pad><pad><pad><pad>
#
# Where is the mattress?
# on frame
# <pad> What is the window covering?</s><pad><pad><pad><pad><pad><pad>
#
# Where is the mattress?
# on box spring
# <pad> What time of day is it?</s><pad><pad><pad><pad>
#
# Where is the mattress?
# bed
# <pad> What is the blue object?</s><pad><pad><pad><pad><pad>
#
# Where is the mattress?
# frame
# <pad> What is the pattern on the bed?</s><pad><pad><pad><pad>
#
# Where is the mattress?
# bed frame
# <pad> What is the bed made of?</s><pad><pad><pad><pad><pad>
#
# Where is the mattress?
# left of center against window
# <pad> Where is the teddy bear?</s><pad><pad><pad>
#
# Where is the mattress?
# bedroom
# <pad> What room is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What flag is shown in the background of this image?
# american
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad>
#
# What flag is shown in the background of this image?
# usa flag
# <pad> What country is this?</s><pad><pad><pad><pad>
#
# What flag is shown in the background of this image?
# too far away to tell
# <pad> Why are there so many people in the picture?</s><pad><pad>
#
# What flag is shown in the background of this image?
# no flag
# <pad> Are there any clouds in the sky?</s><pad><pad><pad><pad>
#
# What flag is shown in the background of this image?
# black
# <pad> What color is the sky?</s><pad><pad><pad>
#
# What flag is shown in the background of this image?
# red
# <pad> What color is the kite?</s><pad><pad><pad><pad><pad>
#
# What flag is shown in the background of this image?
# sky
# <pad> What is in the background?</s><pad><pad><pad><pad><pad>
#
# What flag is shown in the background of this image?
# kites
# <pad> What is in the sky?</s><pad><pad><pad><pad><pad>
#
# Why is there a reflection in the glass?
# mirror
# <pad> What is the red object?</s><pad><pad><pad><pad><pad>
#
# Why is there a reflection in the glass?
# daylight
# <pad> What time of day is it?</s><pad><pad>
#
# Why is there a reflection in the glass?
# sunlight
# <pad> What is the purpose of the yellow object?</s>
#
# Why is there a reflection in the glass?
# lighting
# <pad> What is on the shelf?</s><pad><pad><pad><pad><pad><pad>
#
# Why is there a reflection in the glass?
# light
# <pad> What is on the shelf?</s><pad><pad><pad>
#
# Why is there a reflection in the glass?
# outside light
# <pad> Where is the hydrant?</s><pad><pad><pad><pad>
#
# Why is there a reflection in the glass?
# because of sun
# <pad> Why is the man wearing a watch?</s><pad><pad><pad>
#
# Why is there a reflection in the glass?
# because of light
# <pad> Why is the light on?</s><pad><pad><pad><pad><pad><pad>
#
# Where is the fries?
# basket
# <pad> Where is the ice cream?</s><pad><pad><pad><pad><pad>
#
# Where is the fries?
# in basket
# <pad> Where is the utensil?</s><pad><pad>
#
# Where is the fries?
# in small basket on right
# <pad> Where is the ice cream?</s><pad><pad><pad><pad>
#
# Where is the fries?
# next to sandwich
# <pad> Where is the utensil?</s><pad><pad><pad>
#
# Where is the fries?
# on right
# <pad> Where is the sliced utensil?</s><pad>
#
# Where is the fries?
# to right
# <pad> Where is the sliced utensil?</s><pad>
#
# Where is the fries?
# next to burger
# <pad> Where is the utensil?</s><pad><pad>
#
# Where is the zebra?
# 2
# <pad> How many zebras are there?</s><pad><pad>
#
# Where is the zebra?
# in zoo
# <pad> Where are the zebras?</s><pad><pad><pad><pad>
#
# Where is the zebra?
# center
# <pad> Which zebra is taller?</s><pad><pad><pad>
#
# Where is the zebra?
# zoo
# <pad> Where are the zebras?</s><pad><pad><pad><pad>
#
# Where is the zebra?
# enclosure
# <pad> What is the zebra standing on?</s>
#
# Where is the zebra?
# in pen
# <pad> What are the zebras doing?</s><pad><pad>
#
# Where is the zebra?
# center of picture
# <pad> Where is the zebra?</s><pad><pad><pad><pad><pad>
#
# Where is the zebra?
# reserve
# <pad> Where are the zebras?</s><pad><pad><pad><pad>
#
# What did the girl just do?
# tennis
# <pad> What sport are they playing?</s><pad><pad><pad><pad><pad><pad>
#
# What did the girl just do?
# swing racket
# <pad> What is the man holding?</s><pad><pad><pad>
#
# What did the girl just do?
# hit
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What did the girl just do?
# serve
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What did the girl just do?
# hit ball
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad>
#
# What did the girl just do?
# pose
# <pad> What is the man doing?</s><pad><pad><pad>
#
# What did the girl just do?
# smile
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad>
#
# What did the girl just do?
# win
# <pad> What is the woman doing?</s><pad><pad><pad>
#
# Where is the clove?
# left
# <pad> Which hand is the knife on?</s><pad><pad><pad><pad><pad>
#
# Where is the clove?
# table
# <pad> What is the knife sitting on?</s><pad><pad><pad><pad><pad>
#
# Where is the clove?
# paper towel
# <pad> What is the object on the left side of the picture?</s>
#
# Where is the clove?
# towel
# <pad> What is the paper on?</s><pad><pad><pad><pad><pad><pad>
#
# Where is the clove?
# burnt
# <pad> What is the object on the left?</s><pad><pad><pad>
#
# Where is the clove?
# nowhere
# <pad> What is the knife used for?</s><pad><pad><pad><pad>
#
# Where is the clove?
# no
# <pad> Is this a jar?</s><pad><pad><pad>
#
# Where is the clove?
# not in picture
# <pad> What color is the scissors?</s><pad><pad><pad><pad><pad>
#
# What does the machine do?
# parking payments
# <pad> What is the hydrant used for?</s><pad><pad><pad>
#
# What does the machine do?
# take change for parking
# <pad> What is the purpose of the arrows?</s><pad><pad>
#
# What does the machine do?
# accept parking payment
# <pad> What is the purpose of the sign?</s><pad><pad><pad><pad>
#
# What does the machine do?
# monitors parking
# <pad> What is the purpose of the arrow?</s>
#
# What does the machine do?
# permit parking
# <pad> What is the name of the street?</s><pad><pad><pad><pad>
#
# What does the machine do?
# meters parking time
# <pad> What is the purpose of the arrows?</s><pad><pad>
#
# What does the machine do?
# meters time
# <pad> How long has the meter been parked?</s><pad>
#
# What does the machine do?
# track time
# <pad> What time is it?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What does the machine do?
# work as parking meter
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What does the machine do?
# let you park
# <pad> What is the purpose of the arrow?</s><pad><pad><pad>
#
# Where are the animals in the picture?
# wilderness
# <pad> Where are the zebras?</s><pad>
#
# Where are the animals in the picture?
# safari
# <pad> Where are these animals?</s><pad><pad><pad><pad><pad><pad><pad>
#
# Where are the animals in the picture?
# outdoors
# <pad> Where are the giraffes?</s><pad><pad><pad>
#
# Where are the animals in the picture?
# center
# <pad> Which elephant is the oldest?</s><pad><pad><pad><pad><pad><pad>
#
# Where are the animals in the picture?
# africa
# <pad> Where are the zebras?</s><pad><pad><pad><pad>
#
# Where are the animals in the picture?
# desert
# <pad> What kind of land is this?</s><pad><pad><pad><pad>
#
# Where are the animals in the picture?
# elephants
# <pad> What kind of animals are these?</s><pad><pad><pad><pad><pad>
#
# Where are the men behind the yellow sign on a gray pole?
# in international city
# <pad> Where is this?</s><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Where are the men behind the yellow sign on a gray pole?
# in street
# <pad> Where is the man?</s><pad><pad><pad><pad><pad><pad>
#
# Where are the men behind the yellow sign on a gray pole?
# city
# <pad> Where is this?</s><pad><pad><pad><pad><pad><pad><pad><pad>
#
# Where are the men behind the yellow sign on a gray pole?
# sidewalk
# <pad> What is the man standing on?</s><pad><pad><pad><pad>
#
# Where are the men behind the yellow sign on a gray pole?
# on sidewalk
# <pad> Where are the people?</s><pad><pad><pad><pad>
#
# What pattern is the floor?
# checkered
# <pad> What is the pattern of the floor?</s><pad><pad><pad><pad>
#
# What pattern is the floor?
# octagonal
# <pad> What is the pattern on the toilet seat?</s><pad><pad>
#
# What pattern is the floor?
# circular
# <pad> What shape is the toilet seat?</s><pad><pad><pad><pad><pad>
#
# What pattern is the floor?
# circles
# <pad> What is the pattern on the floor?</s><pad><pad><pad>
#
# What pattern is the floor?
# circle
# <pad> What shape is the toilet seat?</s><pad><pad><pad><pad><pad>
#
# What pattern is the floor?
# tile
# <pad> What is the floor made of?</s><pad><pad>
#
# What pattern is the floor?
# tiles
# <pad> What is the floor made of?</s><pad><pad><pad><pad><pad>
#
# What pattern is the floor?
# flowers
# <pad> What is on the floor?</s><pad><pad><pad><pad><pad><pad>
#
# What state is the trolley working in?
# functioning
# <pad> What is the bus for?</s><pad><pad><pad><pad><pad><pad>
#
# What state is the trolley working in?
# detroit
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What state is the trolley working in?
# new york
# <pad> What country is this?</s><pad><pad><pad><pad>
#
# What state is the trolley working in?
# uk
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad>
#
# What state is the trolley working in?
# england
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad>
#
# What state is the trolley working in?
# arkansas
# <pad> What country is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What state is the trolley working in?
# london
# <pad> What country is this?</s><pad><pad><pad><pad>
#
# What is this girl doing?
# posing for picture
# <pad> What is the man doing?</s><pad><pad><pad>
#
# What is this girl doing?
# posing
# <pad> What is the woman doing?</s><pad><pad><pad>
#
# What is this girl doing?
# swinging
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What is this girl doing?
# batting
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What is this girl doing?
# pretending to play baseball
# <pad> What is the woman doing?</s><pad><pad><pad><pad><pad><pad>
#
# What is this girl doing?
# holding bat
# <pad> What is the woman doing?</s><pad><pad><pad><pad><pad>
#
# What is this girl doing?
# holding baseball bat
# <pad> What is the woman doing?</s><pad><pad><pad><pad><pad>
#
# Why are the eye area pink?
# hairless cat
# <pad> What kind of animal is in the picture?</s>
#
# Why are the eye area pink?
# no fur
# <pad> What color is the cat's hat?</s><pad>
#
# Why are the eye area pink?
# albino
# <pad> What breed of cat is this?</s><pad><pad><pad><pad>
#
# Why are the eye area pink?
# breed of cat
# <pad> What kind of animal is this?</s><pad><pad><pad><pad><pad>
#
# Why are the eye area pink?
# lighting
# <pad> What is hanging from the ceiling?</s><pad><pad><pad><pad><pad>
#
# Why are the eye area pink?
# irritated
# <pad> What is the cat doing?</s><pad><pad><pad><pad><pad><pad>
#
# Why are the eye area pink?
# inflammation
# <pad> What is the cat doing?</s><pad><pad><pad><pad><pad><pad>
#
# Why are there so many desserts on the table?
# buffet
# <pad> What is the woman sitting in?</s><pad><pad><pad><pad>
#
# Why are there so many desserts on the table?
# buffett
# <pad> What is the woman sitting in?</s><pad><pad><pad><pad><pad>
#
# Why are there so many desserts on the table?
# restaurant
# <pad> What room is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# Why are there so many desserts on the table?
# restaurant kitchen
# <pad> What room is this?</s><pad><pad><pad><pad><pad><pad><pad>
#
# Why are there so many desserts on the table?
# dessert bar
# <pad> What is the man holding?</s><pad><pad><pad><pad><pad><pad>
#
# Why are there so many desserts on the table?
# party
# <pad> What is the woman in the background doing?</s><pad><pad><pad>
#
# Why are there so many desserts on the table?
# it's party
# <pad> Why are the people sitting at the table?</s><pad><pad><pad>
#
# Why are there so many desserts on the table?
# having party
# <pad> What are the people doing?</s><pad><pad><pad><pad><pad>
#
# How big is this truck?
# medium size
# <pad> What is the size of the truck?</s><pad><pad><pad><pad>
#
# How big is this truck?
# mid-size
# <pad> How big is the truck?</s><pad><pad><pad><pad><pad>
#
# How big is this truck?
# medium
# <pad> What is the size of the truck?</s><pad><pad><pad>
#
# How big is this truck?
# 15 feet long
# <pad> How tall is the bus?</s><pad><pad><pad><pad><pad><pad>
#
# How big is this truck?
# 10 feet
# <pad> How tall is the truck?</s><pad><pad><pad><pad><pad><pad>
#
# How big is this truck?
# 20 ft
# <pad> How long is the truck?</s><pad><pad><pad><pad><pad><pad>
#
# How big is this truck?
# 7 ft
# <pad> How long is the truck?</s><pad><pad><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# none
# <pad> How many people are in the picture?</s><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# can't see
# <pad> What is the man in the background doing?</s><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# i don't see fruit
# <pad> What is the name of the event?</s><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# no fruit
# <pad> What is the man riding?</s><pad><pad><pad><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# apple
# <pad> What is the name of the street?</s><pad><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# apples
# <pad> What is the man holding?</s><pad><pad><pad><pad><pad><pad>
#
# What type of fruit is being sold at the market?
# banana
# <pad> What is the man holding?</s><pad><pad><pad><pad><pad><pad>
#
# What is on the plate?
# breakfast
# <pad> What is the food for?</s><pad><pad><pad><pad><pad><pad>
#
# What is on the plate?
# breakfast sandwich
# <pad> What is this food?</s><pad><pad><pad><pad><pad><pad><pad>
#
# What is on the plate?
# egg
# <pad> What is on the plate?</s><pad><pad><pad><pad><pad><pad>
#
# What is on the plate?
# egg sandwich
# <pad> What is on the plate?</s><pad><pad><pad><pad><pad>
#
# What is on the plate?
# egg, greens cheese
# <pad> What is on the plate?</s><pad><pad><pad><pad><pad><pad>
#
# What is on the plate?
# eggs
# <pad> What is in the bowl?</s><pad><pad><pad><pad><pad>
#
# What traffic practice is she emphasizing?
# cycling
# <pad> What is the woman doing?</s><pad><pad><pad><pad><pad><pad>
#
# What traffic practice is she emphasizing?
# bike riding
# <pad> What is the woman doing?</s><pad><pad><pad><pad><pad><pad>
#
# What traffic practice is she emphasizing?
# biking
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What traffic practice is she emphasizing?
# bicycling
# <pad> What is the man doing?</s><pad><pad><pad><pad><pad><pad>
#
# What traffic practice is she emphasizing?
# both hands on handlebars
# <pad> Where is the bike?</s><pad><pad><pad><pad><pad><pad>
#
# What traffic practice is she emphasizing?
# bike lane
# <pad> What is the man on the left looking at?</s><pad><pad>
#
# What traffic practice is she emphasizing?
# proper lane
# <pad> Why is the bike on the right side of the road?</s>

# %%
test_data_path = pathlib.Path("/brtx/603-nvme2/estengel/annotator_uncertainty/vqa/dev_from_mturk")
output_path = pathlib.Path("/brtx/602-nvme1/estengel/annotator_uncertainty/models/img2q_t5_small//output/predictions_forced.jsonl")


questions, annotations = read_test_data(test_data_path)
pred_data = read_generations(output_path)
for question, annotation in zip(questions, annotations): 
    qid = question['question_id']
    # print(pred_data.keys())
    pred_text = pred_data[qid]
    print(question['question'])
    print(annotation['answers'][0]['answer'])
    print(pred_text)
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/estengel/annotator_uncertainty/analysis/t5_generations.ipynb Cell 3' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2Bblab/home/estengel/annotator_uncertainty/analysis/t5_generations.ipynb#ch0000006vscode-remote?line=7'>8</a> qid = question['question_id']
#       <a href='vscode-notebook-cell://ssh-remote%2Bblab/home/estengel/annotator_uncertainty/analysis/t5_generations.ipynb#ch0000006vscode-remote?line=8'>9</a> # print(pred_data.keys())
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bblab/home/estengel/annotator_uncertainty/analysis/t5_generations.ipynb#ch0000006vscode-remote?line=9'>10</a> pred_text = pred_data[qid]
#      <a href='vscode-notebook-cell://ssh-remote%2Bblab/home/estengel/annotator_uncertainty/analysis/t5_generations.ipynb#ch0000006vscode-remote?line=10'>11</a> print(question['question'])
#      <a href='vscode-notebook-cell://ssh-remote%2Bblab/home/estengel/annotator_uncertainty/analysis/t5_generations.ipynb#ch0000006vscode-remote?line=11'>12</a> print(annotation['answers'][0]['answer'])
#
# KeyError: '276311000_0'
